# %% [markdown]
# # Preppin' Data 2023 Week 8

# %% [markdown]
# source: https://preppindata.blogspot.com/2023/02/2023-week-8-taking-stock.html

# %% [markdown]
# #### Load data

# %%
import glob
import pandas as pd

# %%
# read all files into separate df and concat
files = glob.glob('Input/*csv')
dfs = []
for file in files:
    df = pd.read_csv(file)
    df['filename'] = file
    dfs.append(df)
df = pd.concat(dfs, ignore_index=True)

# %%
# check values
df
# Out:
#          id first_name   last_name     Ticker                 Sector  Market  \
# 0         1      Vikki     Pascall        RIC       Basic Industries    NYSE
# 1         2     Beulah   Michallat        ELY  Consumer Non-Durables    NYSE
# 2         3     Mignon  Blenkinsop      CPTAG                    NaN  NASDAQ
# 3         4     Willis        Bugg        OAS                 Energy    NYSE
# 4         5    Balduin      Maffei       QQXT                    NaN  NASDAQ
# ...     ...        ...         ...        ...                    ...     ...
# 11995   996   Christel     Sarrell  CLNS^A.CL                    NaN    NYSE
# 11996   997       Rivi        Rame       EMCB                    NaN  NASDAQ
# 11997   998       Doti       Facer        SXT       Basic Industries    NYSE
# 11998   999    Dorothy  Janauschek       KRNT          Capital Goods  NASDAQ
# 11999  1000        Lin      Rosgen       GPAC            Health Care  NASDAQ
#
#                                               Stock Name Market Cap  \
# 0                                   Richmont Mines, Inc.   $458.83M
# 1                                  Callaway Golf Company     $1.14B
# 2                                 Capitala Finance Corp.        NaN
# 3                                   Oasis Petroleum Inc.     $1.94B
# 4      First Trust NASDAQ-100 Ex-Technology Sector In...   $101.07M
# ...                                                  ...        ...
# 11995                             Colony NorthStar, Inc.        NaN
# 11996    WisdomTree Emerging Markets Corporate Bond Fund    $50.49M
# 11997                  Sensient Technologies Corporation     $3.62B
# 11998                                Kornit Digital Ltd.   $643.74M
# 11999                   Global Partner Acquisition Corp.   $193.67M
#
#       Purchase Price                filename
# 0          $78924.65  Input\MOCK_DATA-10.csv
# 1          $89818.72  Input\MOCK_DATA-10.csv
# 2          $53160.64  Input\MOCK_DATA-10.csv
# 3          $23636.92  Input\MOCK_DATA-10.csv
# 4          $65979.23  Input\MOCK_DATA-10.csv
# ...              ...                     ...
# 11995      $60683.35     Input\MOCK_DATA.csv
# 11996      $55605.12     Input\MOCK_DATA.csv
# 11997      $63432.98     Input\MOCK_DATA.csv
# 11998      $97859.28     Input\MOCK_DATA.csv
# 11999      $73954.07     Input\MOCK_DATA.csv
#
# [12000 rows x 10 columns]

# %% [markdown]
# #### Create date

# %%
# get month of file name
df['File Date'] = df['filename'].str.split('-', expand=True)[1]

# %%
# get month of file name
df['File Date'] = df['File Date'].str.split('.', expand=True)[0]

# %%
# replace null with 1 for jan
df.loc[df['filename'] == 'Input\MOCK_DATA.csv', 'File Date'] = 1

# %%
df = df.rename(columns = {'File Date':'Month'})

# %%
df
# Out:
#          id first_name   last_name     Ticker                 Sector  Market  \
# 0         1      Vikki     Pascall        RIC       Basic Industries    NYSE
# 1         2     Beulah   Michallat        ELY  Consumer Non-Durables    NYSE
# 2         3     Mignon  Blenkinsop      CPTAG                    NaN  NASDAQ
# 3         4     Willis        Bugg        OAS                 Energy    NYSE
# 4         5    Balduin      Maffei       QQXT                    NaN  NASDAQ
# ...     ...        ...         ...        ...                    ...     ...
# 11995   996   Christel     Sarrell  CLNS^A.CL                    NaN    NYSE
# 11996   997       Rivi        Rame       EMCB                    NaN  NASDAQ
# 11997   998       Doti       Facer        SXT       Basic Industries    NYSE
# 11998   999    Dorothy  Janauschek       KRNT          Capital Goods  NASDAQ
# 11999  1000        Lin      Rosgen       GPAC            Health Care  NASDAQ
#
#                                               Stock Name Market Cap  \
# 0                                   Richmont Mines, Inc.   $458.83M
# 1                                  Callaway Golf Company     $1.14B
# 2                                 Capitala Finance Corp.        NaN
# 3                                   Oasis Petroleum Inc.     $1.94B
# 4      First Trust NASDAQ-100 Ex-Technology Sector In...   $101.07M
# ...                                                  ...        ...
# 11995                             Colony NorthStar, Inc.        NaN
# 11996    WisdomTree Emerging Markets Corporate Bond Fund    $50.49M
# 11997                  Sensient Technologies Corporation     $3.62B
# 11998                                Kornit Digital Ltd.   $643.74M
# 11999                   Global Partner Acquisition Corp.   $193.67M
#
#       Purchase Price                filename Month
# 0          $78924.65  Input\MOCK_DATA-10.csv    10
# 1          $89818.72  Input\MOCK_DATA-10.csv    10
# 2          $53160.64  Input\MOCK_DATA-10.csv    10
# 3          $23636.92  Input\MOCK_DATA-10.csv    10
# 4          $65979.23  Input\MOCK_DATA-10.csv    10
# ...              ...                     ...   ...
# 11995      $60683.35     Input\MOCK_DATA.csv     1
# 11996      $55605.12     Input\MOCK_DATA.csv     1
# 11997      $63432.98     Input\MOCK_DATA.csv     1
# 11998      $97859.28     Input\MOCK_DATA.csv     1
# 11999      $73954.07     Input\MOCK_DATA.csv     1
#
# [12000 rows x 11 columns]

# %%
df['File Date'] = pd.to_datetime(dict(year='2023',month=df['Month'],day='01'))

# %%
df = df.drop(['filename','Month'], axis=1)

# %%
df
# Out:
#          id first_name   last_name     Ticker                 Sector  Market  \
# 0         1      Vikki     Pascall        RIC       Basic Industries    NYSE
# 1         2     Beulah   Michallat        ELY  Consumer Non-Durables    NYSE
# 2         3     Mignon  Blenkinsop      CPTAG                    NaN  NASDAQ
# 3         4     Willis        Bugg        OAS                 Energy    NYSE
# 4         5    Balduin      Maffei       QQXT                    NaN  NASDAQ
# ...     ...        ...         ...        ...                    ...     ...
# 11995   996   Christel     Sarrell  CLNS^A.CL                    NaN    NYSE
# 11996   997       Rivi        Rame       EMCB                    NaN  NASDAQ
# 11997   998       Doti       Facer        SXT       Basic Industries    NYSE
# 11998   999    Dorothy  Janauschek       KRNT          Capital Goods  NASDAQ
# 11999  1000        Lin      Rosgen       GPAC            Health Care  NASDAQ
#
#                                               Stock Name Market Cap  \
# 0                                   Richmont Mines, Inc.   $458.83M
# 1                                  Callaway Golf Company     $1.14B
# 2                                 Capitala Finance Corp.        NaN
# 3                                   Oasis Petroleum Inc.     $1.94B
# 4      First Trust NASDAQ-100 Ex-Technology Sector In...   $101.07M
# ...                                                  ...        ...
# 11995                             Colony NorthStar, Inc.        NaN
# 11996    WisdomTree Emerging Markets Corporate Bond Fund    $50.49M
# 11997                  Sensient Technologies Corporation     $3.62B
# 11998                                Kornit Digital Ltd.   $643.74M
# 11999                   Global Partner Acquisition Corp.   $193.67M
#
#       Purchase Price  File Date
# 0          $78924.65 2023-10-01
# 1          $89818.72 2023-10-01
# 2          $53160.64 2023-10-01
# 3          $23636.92 2023-10-01
# 4          $65979.23 2023-10-01
# ...              ...        ...
# 11995      $60683.35 2023-01-01
# 11996      $55605.12 2023-01-01
# 11997      $63432.98 2023-01-01
# 11998      $97859.28 2023-01-01
# 11999      $73954.07 2023-01-01
#
# [12000 rows x 10 columns]

# %% [markdown]
# #### Clean the Market Cap

# %%
# drop rows if null
df = df.dropna(subset=['Market Cap'])

# %%
# drop n/a
df = df.drop(df[df['Market Cap'] == 'n/a'].index)

# %%
df
# Out:
#          id first_name   last_name Ticker                 Sector  Market  \
# 0         1      Vikki     Pascall    RIC       Basic Industries    NYSE
# 1         2     Beulah   Michallat    ELY  Consumer Non-Durables    NYSE
# 3         4     Willis        Bugg    OAS                 Energy    NYSE
# 4         5    Balduin      Maffei   QQXT                    NaN  NASDAQ
# 5         6    Octavia       Rawll  IMKTA      Consumer Services  NASDAQ
# ...     ...        ...         ...    ...                    ...     ...
# 11994   995        Ben    Matuszak   ENBL       Public Utilities    NYSE
# 11996   997       Rivi        Rame   EMCB                    NaN  NASDAQ
# 11997   998       Doti       Facer    SXT       Basic Industries    NYSE
# 11998   999    Dorothy  Janauschek   KRNT          Capital Goods  NASDAQ
# 11999  1000        Lin      Rosgen   GPAC            Health Care  NASDAQ
#
#                                               Stock Name Market Cap  \
# 0                                   Richmont Mines, Inc.   $458.83M
# 1                                  Callaway Golf Company     $1.14B
# 3                                   Oasis Petroleum Inc.     $1.94B
# 4      First Trust NASDAQ-100 Ex-Technology Sector In...   $101.07M
# 5                           Ingles Markets, Incorporated   $687.82M
# ...                                                  ...        ...
# 11994                      Enable Midstream Partners, LP     $6.43B
# 11996    WisdomTree Emerging Markets Corporate Bond Fund    $50.49M
# 11997                  Sensient Technologies Corporation     $3.62B
# 11998                                Kornit Digital Ltd.   $643.74M
# 11999                   Global Partner Acquisition Corp.   $193.67M
#
#       Purchase Price  File Date
# 0          $78924.65 2023-10-01
# 1          $89818.72 2023-10-01
# 3          $23636.92 2023-10-01
# 4          $65979.23 2023-10-01
# 5          $41824.21 2023-10-01
# ...              ...        ...
# 11994      $14609.25 2023-01-01
# 11996      $55605.12 2023-01-01
# 11997      $63432.98 2023-01-01
# 11998      $97859.28 2023-01-01
# 11999      $73954.07 2023-01-01
#
# [10109 rows x 10 columns]

# %%
df = df.rename(columns = {'Market Cap':'Market Capitalisation'})

# %%
df
# Out:
#          id first_name   last_name Ticker                 Sector  Market  \
# 0         1      Vikki     Pascall    RIC       Basic Industries    NYSE
# 1         2     Beulah   Michallat    ELY  Consumer Non-Durables    NYSE
# 3         4     Willis        Bugg    OAS                 Energy    NYSE
# 4         5    Balduin      Maffei   QQXT                    NaN  NASDAQ
# 5         6    Octavia       Rawll  IMKTA      Consumer Services  NASDAQ
# ...     ...        ...         ...    ...                    ...     ...
# 11994   995        Ben    Matuszak   ENBL       Public Utilities    NYSE
# 11996   997       Rivi        Rame   EMCB                    NaN  NASDAQ
# 11997   998       Doti       Facer    SXT       Basic Industries    NYSE
# 11998   999    Dorothy  Janauschek   KRNT          Capital Goods  NASDAQ
# 11999  1000        Lin      Rosgen   GPAC            Health Care  NASDAQ
#
#                                               Stock Name  \
# 0                                   Richmont Mines, Inc.
# 1                                  Callaway Golf Company
# 3                                   Oasis Petroleum Inc.
# 4      First Trust NASDAQ-100 Ex-Technology Sector In...
# 5                           Ingles Markets, Incorporated
# ...                                                  ...
# 11994                      Enable Midstream Partners, LP
# 11996    WisdomTree Emerging Markets Corporate Bond Fund
# 11997                  Sensient Technologies Corporation
# 11998                                Kornit Digital Ltd.
# 11999                   Global Partner Acquisition Corp.
#
#       Market Capitalisation Purchase Price  File Date
# 0                  $458.83M      $78924.65 2023-10-01
# 1                    $1.14B      $89818.72 2023-10-01
# 3                    $1.94B      $23636.92 2023-10-01
# 4                  $101.07M      $65979.23 2023-10-01
# 5                  $687.82M      $41824.21 2023-10-01
# ...                     ...            ...        ...
# 11994                $6.43B      $14609.25 2023-01-01
# 11996               $50.49M      $55605.12 2023-01-01
# 11997                $3.62B      $63432.98 2023-01-01
# 11998              $643.74M      $97859.28 2023-01-01
# 11999              $193.67M      $73954.07 2023-01-01
#
# [10109 rows x 10 columns]

# %% [markdown]
# #### Categorise the Purchase Price into groupings

# %%
# remove dollar sign
df['Purchase Price'] = df['Purchase Price'].str.split('$',expand=True)[1].astype(float)

# %%
def purchase_price_cat(x):
    if x['Purchase Price'] > 0.00 and x['Purchase Price'] <= 24999.99:
        return 'Small'
    elif x['Purchase Price'] <= 49999.99:
        return 'Medium'
    elif x['Purchase Price'] <= 74999.99:
        return 'Large'
    elif x['Purchase Price'] <= 100000.00:
        return 'Very Large'

# %%
df['Purchase Price Category'] = df.apply(lambda x: purchase_price_cat(x), axis=1)

# %%
df.head()
# Out:
#    id first_name  last_name Ticker                 Sector  Market  \
# 0   1      Vikki    Pascall    RIC       Basic Industries    NYSE
# 1   2     Beulah  Michallat    ELY  Consumer Non-Durables    NYSE
# 3   4     Willis       Bugg    OAS                 Energy    NYSE
# 4   5    Balduin     Maffei   QQXT                    NaN  NASDAQ
# 5   6    Octavia      Rawll  IMKTA      Consumer Services  NASDAQ
#
#                                           Stock Name Market Capitalisation  \
# 0                               Richmont Mines, Inc.              $458.83M
# 1                              Callaway Golf Company                $1.14B
# 3                               Oasis Petroleum Inc.                $1.94B
# 4  First Trust NASDAQ-100 Ex-Technology Sector In...              $101.07M
# 5                       Ingles Markets, Incorporated              $687.82M
#
#    Purchase Price  File Date Purchase Price Category
# 0        78924.65 2023-10-01              Very Large
# 1        89818.72 2023-10-01              Very Large
# 3        23636.92 2023-10-01                   Small
# 4        65979.23 2023-10-01                   Large
# 5        41824.21 2023-10-01                  Medium

# %% [markdown]
# #### Categorise the Market Cap into groupings

# %%
# remove dollar sign
df['Market Capitalisation'] = df['Market Capitalisation'].str.split('$',expand=True)[1]

# %%
# get billions or millions
df['Market Cap Agg'] = df['Market Capitalisation'].str[-1:]

# %%
# remove letter
df['Market Capitalisation'] = df['Market Capitalisation'].str[:-1]

# %%
def market_cap_val(x):
    """function to expand the value based on aggregation"""
    if x['Market Cap Agg'] == 'B':
        return x['Market Capitalisation'] * 1000000000
    elif x['Market Cap Agg'] == 'M':
        return x['Market Capitalisation'] * 1000000

# %%
# convert to float
df['Market Capitalisation'] = df['Market Capitalisation'].astype(float)

# %%
# apply function
df['Market Cap Value'] = df.apply(lambda x: market_cap_val(x), axis=1)

# %%
df.head()
# Out:
#    id first_name  last_name Ticker                 Sector  Market  \
# 0   1      Vikki    Pascall    RIC       Basic Industries    NYSE
# 1   2     Beulah  Michallat    ELY  Consumer Non-Durables    NYSE
# 3   4     Willis       Bugg    OAS                 Energy    NYSE
# 4   5    Balduin     Maffei   QQXT                    NaN  NASDAQ
# 5   6    Octavia      Rawll  IMKTA      Consumer Services  NASDAQ
#
#                                           Stock Name  Market Capitalisation  \
# 0                               Richmont Mines, Inc.                 458.83
# 1                              Callaway Golf Company                   1.14
# 3                               Oasis Petroleum Inc.                   1.94
# 4  First Trust NASDAQ-100 Ex-Technology Sector In...                 101.07
# 5                       Ingles Markets, Incorporated                 687.82
#
#    Purchase Price  File Date Purchase Price Category Market Cap Agg  \
# 0        78924.65 2023-10-01              Very Large              M
# 1        89818.72 2023-10-01              Very Large              B
# 3        23636.92 2023-10-01                   Small              B
# 4        65979.23 2023-10-01                   Large              M
# 5        41824.21 2023-10-01                  Medium              M
#
#    Market Cap Value
# 0      4.588300e+08
# 1      1.140000e+09
# 3      1.940000e+09
# 4      1.010700e+08
# 5      6.878200e+08

# %%
# drop columns
df = df.drop(['Market Cap Agg','Market Capitalisation'], axis=1)

# %%
df = df.rename(columns={'Market Cap Value':'Market Capitalisation'})

# %%
df.head()
# Out:
#    id first_name  last_name Ticker                 Sector  Market  \
# 0   1      Vikki    Pascall    RIC       Basic Industries    NYSE
# 1   2     Beulah  Michallat    ELY  Consumer Non-Durables    NYSE
# 3   4     Willis       Bugg    OAS                 Energy    NYSE
# 4   5    Balduin     Maffei   QQXT                    NaN  NASDAQ
# 5   6    Octavia      Rawll  IMKTA      Consumer Services  NASDAQ
#
#                                           Stock Name  Purchase Price  \
# 0                               Richmont Mines, Inc.        78924.65
# 1                              Callaway Golf Company        89818.72
# 3                               Oasis Petroleum Inc.        23636.92
# 4  First Trust NASDAQ-100 Ex-Technology Sector In...        65979.23
# 5                       Ingles Markets, Incorporated        41824.21
#
#    File Date Purchase Price Category  Market Capitalisation
# 0 2023-10-01              Very Large           4.588300e+08
# 1 2023-10-01              Very Large           1.140000e+09
# 3 2023-10-01                   Small           1.940000e+09
# 4 2023-10-01                   Large           1.010700e+08
# 5 2023-10-01                  Medium           6.878200e+08

# %% [markdown]
# #### Categorise the Market Cap into groupings

# %%
def market_cap_cat(x):
    if x['Market Capitalisation'] < 100000000:
        return 'Small'
    elif x['Market Capitalisation'] < 1000000000:
        return 'Medium'
    elif x['Market Capitalisation'] < 100000000000:
        return 'Large'
    elif x['Market Capitalisation'] >= 100000000000:
        return 'Huge'

# %%
df['Market Capitalisation Category'] = df.apply(lambda x: market_cap_cat(x), axis=1)

# %%
df.head()
# Out:
#    id first_name  last_name Ticker                 Sector  Market  \
# 0   1      Vikki    Pascall    RIC       Basic Industries    NYSE
# 1   2     Beulah  Michallat    ELY  Consumer Non-Durables    NYSE
# 3   4     Willis       Bugg    OAS                 Energy    NYSE
# 4   5    Balduin     Maffei   QQXT                    NaN  NASDAQ
# 5   6    Octavia      Rawll  IMKTA      Consumer Services  NASDAQ
#
#                                           Stock Name  Purchase Price  \
# 0                               Richmont Mines, Inc.        78924.65
# 1                              Callaway Golf Company        89818.72
# 3                               Oasis Petroleum Inc.        23636.92
# 4  First Trust NASDAQ-100 Ex-Technology Sector In...        65979.23
# 5                       Ingles Markets, Incorporated        41824.21
#
#    File Date Purchase Price Category  Market Capitalisation  \
# 0 2023-10-01              Very Large           4.588300e+08
# 1 2023-10-01              Very Large           1.140000e+09
# 3 2023-10-01                   Small           1.940000e+09
# 4 2023-10-01                   Large           1.010700e+08
# 5 2023-10-01                  Medium           6.878200e+08
#
#   Market Capitalisation Category
# 0                         Medium
# 1                          Large
# 3                          Large
# 4                         Medium
# 5                         Medium

# %% [markdown]
# #### Rank the highest 5 purchases per combination of: file date, Purchase Price Categorisation and Market Capitalisation Categorisation.

# %%
df['Rank'] = df.groupby(['File Date', 'Purchase Price Category','Market Capitalisation Category'])['Purchase Price'].rank(ascending=False)

# %% [markdown]
# #### Output only records with a rank of 1 to 5

# %%
df2 = df[df['Rank']<=5]

# %%
df2 = df2.drop(['id','first_name','last_name'], axis=1)

# %%
df2.to_csv('2023W08_output.csv', index=False)
