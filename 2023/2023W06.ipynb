# %% [markdown]
# # Preppin' Data 2023 Week 6

# %% [markdown]
# #### Load data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DSB Customer Survey.csv')

# %%
df.head()
# Out:
#    Customer ID  Mobile App - Ease of Use  Mobile App - Ease of Access  \
# 0       535084                         2                            1
# 1       250892                         3                            5
# 2       544191                         5                            3
# 3       949343                         2                            5
# 4       915305                         3                            1
#
#    Mobile App - Navigation  Mobile App - Likelihood to Recommend  \
# 0                        5                                     4
# 1                        4                                     4
# 2                        4                                     4
# 3                        4                                     3
# 4                        2                                     1
#
#    Mobile App - Overall Rating  Online Interface - Ease of Use  \
# 0                            1                               4
# 1                            2                               5
# 2                            1                               3
# 3                            1                               1
# 4                            1                               4
#
#    Online Interface - Ease of Access  Online Interface - Navigation  \
# 0                                  4                              5
# 1                                  5                              2
# 2                                  3                              2
# 3                                  4                              3
# 4                                  2                              4
#
#    Online Interface - Likelihood to Recommend  \
# 0                                           2
# 1                                           4
# 2                                           3
# 3                                           5
# 4                                           3
#
#    Online Interface - Overall Rating
# 0                                  3
# 1                                  3
# 2                                  1
# 3                                  1
# 4                                  2

# %% [markdown]
# #### Reshape to have Mobile and Online Interface in one column

# %%
df_m = df[['Customer ID','Mobile App - Ease of Use','Mobile App - Ease of Access',\
           'Mobile App - Navigation','Mobile App - Likelihood to Recommend',\
           'Mobile App - Overall Rating']]

# %%
df_m = df_m.melt(id_vars=['Customer ID'], var_name='Mobile App', value_name='Mobile App Value')

# %%
df_m['Mobile App'] = df_m['Mobile App'].str.replace('Mobile App - ', '')

# %%
df_m
# Out:
#       Customer ID      Mobile App  Mobile App Value
# 0          535084     Ease of Use                 2
# 1          250892     Ease of Use                 3
# 2          544191     Ease of Use                 5
# 3          949343     Ease of Use                 2
# 4          915305     Ease of Use                 3
# ...           ...             ...               ...
# 3835       374015  Overall Rating                 2
# 3836       144922  Overall Rating                 4
# 3837       421323  Overall Rating                 3
# 3838       707580  Overall Rating                 5
# 3839       123417  Overall Rating                 4
#
# [3840 rows x 3 columns]

# %% [markdown]
# #### Online Interface

# %%
df_o = df[['Customer ID','Online Interface - Ease of Use','Online Interface - Ease of Access',\
           'Online Interface - Navigation','Online Interface - Likelihood to Recommend',\
           'Online Interface - Overall Rating']]

# %%
df_o = df_o.melt(id_vars=['Customer ID'], var_name='Online Interface', value_name='Online Interface Value')

# %%
df_o['Online Interface'] = df_o['Online Interface'].str.replace('Online Interface - ', '')

# %%
df_o
# Out:
#       Customer ID Online Interface  Online Interface Value
# 0          535084      Ease of Use                       4
# 1          250892      Ease of Use                       5
# 2          544191      Ease of Use                       3
# 3          949343      Ease of Use                       1
# 4          915305      Ease of Use                       4
# ...           ...              ...                     ...
# 3835       374015   Overall Rating                       1
# 3836       144922   Overall Rating                       3
# 3837       421323   Overall Rating                       2
# 3838       707580   Overall Rating                       1
# 3839       123417   Overall Rating                       5
#
# [3840 rows x 3 columns]

# %% [markdown]
# #### Merge back together

# %%
df1 = pd.merge(df_m, df_o, how='left', left_on=['Customer ID', 'Mobile App'],\
               right_on=['Customer ID','Online Interface'])

# %%
df1
# Out:
#       Customer ID      Mobile App  Mobile App Value Online Interface  \
# 0          535084     Ease of Use                 2      Ease of Use
# 1          250892     Ease of Use                 3      Ease of Use
# 2          544191     Ease of Use                 5      Ease of Use
# 3          949343     Ease of Use                 2      Ease of Use
# 4          915305     Ease of Use                 3      Ease of Use
# ...           ...             ...               ...              ...
# 3835       374015  Overall Rating                 2   Overall Rating
# 3836       144922  Overall Rating                 4   Overall Rating
# 3837       421323  Overall Rating                 3   Overall Rating
# 3838       707580  Overall Rating                 5   Overall Rating
# 3839       123417  Overall Rating                 4   Overall Rating
#
#       Online Interface Value
# 0                          4
# 1                          5
# 2                          3
# 3                          1
# 4                          4
# ...                      ...
# 3835                       1
# 3836                       3
# 3837                       2
# 3838                       1
# 3839                       5
#
# [3840 rows x 5 columns]

# %%
# test one value
df1.loc[df1['Customer ID'] == 535084]
# Out:
#       Customer ID               Mobile App  Mobile App Value  \
# 0          535084              Ease of Use                 2
# 768        535084           Ease of Access                 1
# 1536       535084               Navigation                 5
# 2304       535084  Likelihood to Recommend                 4
# 3072       535084           Overall Rating                 1
#
#              Online Interface  Online Interface Value
# 0                 Ease of Use                       4
# 768            Ease of Access                       4
# 1536               Navigation                       5
# 2304  Likelihood to Recommend                       2
# 3072           Overall Rating                       3

# %% [markdown]
# #### Drop Overall Rating rows

# %%
#find index position
or_names = df1[df1['Mobile App'] == 'Overall Rating'].index

# %%
# drop based on index position
df1.drop(or_names, inplace = True)

# %%
df1
# Out:
#       Customer ID               Mobile App  Mobile App Value  \
# 0          535084              Ease of Use                 2
# 1          250892              Ease of Use                 3
# 2          544191              Ease of Use                 5
# 3          949343              Ease of Use                 2
# 4          915305              Ease of Use                 3
# ...           ...                      ...               ...
# 3067       374015  Likelihood to Recommend                 5
# 3068       144922  Likelihood to Recommend                 2
# 3069       421323  Likelihood to Recommend                 1
# 3070       707580  Likelihood to Recommend                 4
# 3071       123417  Likelihood to Recommend                 3
#
#              Online Interface  Online Interface Value
# 0                 Ease of Use                       4
# 1                 Ease of Use                       5
# 2                 Ease of Use                       3
# 3                 Ease of Use                       1
# 4                 Ease of Use                       4
# ...                       ...                     ...
# 3067  Likelihood to Recommend                       5
# 3068  Likelihood to Recommend                       4
# 3069  Likelihood to Recommend                       1
# 3070  Likelihood to Recommend                       4
# 3071  Likelihood to Recommend                       3
#
# [3072 rows x 5 columns]

# %% [markdown]
# #### Calculate the Average Ratings for each platform for each customer

# %%
df1['Mobile App Average'] = df1.groupby('Customer ID')['Mobile App Value'].transform('mean')

# %%
df1['Online Interface Average'] = df1.groupby('Customer ID')['Online Interface Value'].transform('mean')

# %%
# test one value
df1.loc[df1['Customer ID'] == 535084]
# Out:
#       Customer ID               Mobile App  Mobile App Value  \
# 0          535084              Ease of Use                 2
# 768        535084           Ease of Access                 1
# 1536       535084               Navigation                 5
# 2304       535084  Likelihood to Recommend                 4
#
#              Online Interface  Online Interface Value  Mobile App Average  \
# 0                 Ease of Use                       4                 3.0
# 768            Ease of Access                       4                 3.0
# 1536               Navigation                       5                 3.0
# 2304  Likelihood to Recommend                       2                 3.0
#
#       Online Interface Average
# 0                         3.75
# 768                       3.75
# 1536                      3.75
# 2304                      3.75

# %% [markdown]
# #### Calculate the difference in Average Rating between Mobile App and Online Interface for each customer

# %%
df1['Difference'] = df1['Mobile App Average'] - df1['Online Interface Average']

# %%
df1.head()
# Out:
#    Customer ID   Mobile App  Mobile App Value Online Interface  \
# 0       535084  Ease of Use                 2      Ease of Use
# 1       250892  Ease of Use                 3      Ease of Use
# 2       544191  Ease of Use                 5      Ease of Use
# 3       949343  Ease of Use                 2      Ease of Use
# 4       915305  Ease of Use                 3      Ease of Use
#
#    Online Interface Value  Mobile App Average  Online Interface Average  \
# 0                       4                3.00                      3.75
# 1                       5                4.00                      4.00
# 2                       3                4.00                      2.75
# 3                       1                3.50                      3.25
# 4                       4                1.75                      3.25
#
#    Difference
# 0       -0.75
# 1        0.00
# 2        1.25
# 3        0.25
# 4       -1.50

# %% [markdown]
# #### Categorise customers as being:
# Mobile App Superfans if the difference is greater than or equal to 2 in the Mobile App's favour
# Mobile App Fans if difference >= 1
# Online Interface Fan
# Online Interface Superfan
# Neutral if difference is between 0 and 1

# %%
# set the conditions
conditions = [
    (df1['Difference'] >= 2),
    (df1['Difference'] >= 1),
    (df1['Difference'] <= -2),
    (df1['Difference'] <= -1),
    (df1['Difference'] > -1) & (df1['Difference'] < 1)
]

#specify what values to return
values = ['Mobile App Superfan','Mobile App Fan','Online Interface Superfan','Online Interface Fan','Neutral']

# apply to column
df1['Preference'] = np.select(conditions, values)

# %%
df1.head()
# Out:
#    Customer ID   Mobile App  Mobile App Value Online Interface  \
# 0       535084  Ease of Use                 2      Ease of Use
# 1       250892  Ease of Use                 3      Ease of Use
# 2       544191  Ease of Use                 5      Ease of Use
# 3       949343  Ease of Use                 2      Ease of Use
# 4       915305  Ease of Use                 3      Ease of Use
#
#    Online Interface Value  Mobile App Average  Online Interface Average  \
# 0                       4                3.00                      3.75
# 1                       5                4.00                      4.00
# 2                       3                4.00                      2.75
# 3                       1                3.50                      3.25
# 4                       4                1.75                      3.25
#
#    Difference            Preference
# 0       -0.75               Neutral
# 1        0.00               Neutral
# 2        1.25        Mobile App Fan
# 3        0.25               Neutral
# 4       -1.50  Online Interface Fan

# %% [markdown]
# #### Calculate the Percent of Total customers in each category, rounded to 1 decimal place

# %%
df2 = df1[['Customer ID','Preference']]

# %%
df2.head()
# Out:
#    Customer ID            Preference
# 0       535084               Neutral
# 1       250892               Neutral
# 2       544191        Mobile App Fan
# 3       949343               Neutral
# 4       915305  Online Interface Fan

# %%
df2['Total'] = df2.groupby('Preference')['Customer ID'].transform('count')
# Out:
# C:\Users\amar\AppData\Local\Temp\ipykernel_11004\451441864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Total'] = df2.groupby('Preference')['Customer ID'].transform('count')

# %%
df2 = df2.drop('Customer ID', axis=1)

# %%
df2 = df2.drop_duplicates()

# %%
df2
# Out:
#                    Preference  Total
# 0                     Neutral   1956
# 2              Mobile App Fan    504
# 4        Online Interface Fan    452
# 21  Online Interface Superfan     80
# 73        Mobile App Superfan     80

# %%
df2['% of Total'] = round(df2['Total']/df2['Total'].sum()*100, 1)

# %%
df2
# Out:
#                    Preference  Total  Table Total  % of Total
# 0                     Neutral   1956         1956        63.7
# 2              Mobile App Fan    504          504        16.4
# 4        Online Interface Fan    452          452        14.7
# 21  Online Interface Superfan     80           80         2.6
# 73        Mobile App Superfan     80           80         2.6

# %% [markdown]
# #### Output

# %%
df2[['Preference','% of Total']].to_csv('2023W06_output.csv', index=False)
